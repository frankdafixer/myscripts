# %%
import requests

url = "https://api.ebird.org/v2/data/obs/US-NY/recent"

payload={}
headers = {
  'X-eBirdApiToken': 't9887m4c9h68'
}

response = requests.request("GET", url, headers=headers, data=payload)




import json

def jprint(obj):
    # create a formatted string of the Python JSON object
    text = json.dumps(obj, sort_keys=True, indent=4)
    print(text)

jprint(response.json())
# Out:
# [
#     {
#         "comName": "Ring-billed Gull",
#         "howMany": 2,
#         "lat": 42.9340807,
#         "lng": -73.7905473,
#         "locId": "L5704619",
#         "locName": "Round Lake, boat launch (Saratoga Co.)",
#         "locationPrivate": false,
#         "obsDt": "2022-12-18 19:58",
#         "obsReviewed": false,
#         "obsValid": true,
#         "sciName": "Larus delawarensis",
#         "speciesCode": "ribgul",
#         "subId": "S124226669"
#     },
#     {
#         "comName": "Herring Gull",
#         "howMany": 7,
#         "lat": 42.9340807,
#         "lng": -73.7905473,
#         "locId": "L5704619",
#         "locName": "Round Lake, boat launch (Saratoga Co.)",
#         "locationPrivate": false,
#         "obsDt": "2022-12-18 19:58",
#         "obsReviewed": false,
#         "obsValid": true,
#         "sciName": "Larus argentatus",
#         "speciesCode": "hergul",
#         "subId": "S124226669"
#     },
#     {
# ...

# %%
url = "https://www.googleapis.com/books/v1/mylibrary/bookshelves"

payload={'key': 'AIzaSyC4udocLm0v0kEY6LOWIWCu0qT-7IF3UWw'}
headers = {
  'Authorization':'310107181270-98il3ua4s5ojgru6kg4f9kdjmcf0d8c3.apps.googleusercontent.com'
}

response = requests.request("GET", url, headers=headers, params=payload)
print(response.url)
print(response.status_code)
# Out:
# https://www.googleapis.com/books/v1/mylibrary/bookshelves?key=AIzaSyC4udocLm0v0kEY6LOWIWCu0qT-7IF3UWw
# 401
